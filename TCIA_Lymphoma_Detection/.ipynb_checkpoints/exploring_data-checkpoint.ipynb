# %% [markdown]
# # Exploring our Data
# A quick notebook wherein we look at our training images.

# %%
# %pylab inline
import pandas as pd
import cv2
from cv2 import imread
from matplotlib.pyplot import imshow
import os
from tqdm import tqdm
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### First, load the data:

# %%
train_pos_dir = './data/ct_balanced/train/1'
train_neg_dir = './data/ct_balanced/train/0'

pos_imgs = [imread(os.path.join(train_pos_dir,f)) for f in tqdm(os.listdir(train_pos_dir))]
neg_imgs = [imread(os.path.join(train_neg_dir,f)) for f in tqdm(os.listdir(train_neg_dir))]
# Out:
# ...
# 100%|██████████| 495/495 [00:04<00:00, 118.60it/s]

# %% [markdown]
# ### Viewing a Batch:

# %%
from fastai.vision import *
data = ImageDataBunch.from_folder('./data/ct_balanced/')
data.show_batch()

# %% [markdown]
# And what's the shape of each of these image arrays?

# %%
import glob
imread(np.random.choice(glob.glob('./data/ct_balanced/valid/1/*'))).shape
# Out:
# (512, 512, 3)

# %% [markdown]
# ### Done!
