# %% [markdown]
# # Sandbox
# This is a sandbox notebook for testing ideas and tangential bits of code. Not to be run in sequence.

# %%
# %pylab inline
import pandas as pd
import pandas
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# !pip install pydicom
# Out:
# Collecting pydicom
#   Downloading https://files.pythonhosted.org/packages/fc/d5/da1fdf3b967e324ee47a7ad9553c9b94c1193b6b98afd9eeda0efb76b9f7/pydicom-1.3.0-py2.py3-none-any.whl (7.1MB)
#      |████████████████████████████████| 7.1MB 1.7MB/s eta 0:00:01
# Installing collected packages: pydicom
# Successfully installed pydicom-1.3.0

# %%
from tciaclient import TCIAClient

# %%
KEY = '65547902-6d69-4f5b-9857-fb1e724d3b90' 
client = TCIAClient(apiKey = KEY, baseUrl="https://services.cancerimagingarchive.net/services/v3",resource = "TCIA")

# %%
import urllib.request, urllib.error, urllib.parse, urllib.request, urllib.parse, urllib.error,sys
import json

# %%
def getResponseString(response):
    if response.getcode() is not 200:
        raise ValueError("Server returned an error")
    else:
        return response.read()

# %%
response = client.get_collection_values()
strRespCollections = getResponseString(response)

collections = pandas.io.json.read_json(strRespCollections)
# Out:
# https://services.cancerimagingarchive.net/services/v3/TCIA/query/getCollectionValues?format=json

# %%
collections[collections['Collection'].str.contains('Lymph')]
# Out:
#         Collection
# 50  CT Lymph Nodes

# %%
lymph_series_name = collections['Collection'].loc[50]
lymph_series_name
# Out:
# 'CT Lymph Nodes'

# %%
#Grab the series for CT Lymph Nodes
response = client.get_series(modality="CT", collection=lymph_series_name)
strRespSeries = getResponseString(response)
pdfSeries = pandas.io.json.read_json(strRespSeries)
# Out:
# https://services.cancerimagingarchive.net/services/v3/TCIA/query/getSeries?Collection=CT+Lymph+Nodes&Modality=CT&format=json

# %%
#Looks like the majority of the data sits above
#300 images, with some outliers at the bottom.
pdfSeries['ImageCount'].plot(kind='hist')

# %%
#You can filter like this:
pdfSeries[pdfSeries['ImageCount']>300].head()
# Out:
#   BodyPartExamined      Collection  ImageCount Modality  \
# 0          ABDOMEN  CT Lymph Nodes         717       CT
# 1          ABDOMEN  CT Lymph Nodes         517       CT
# 2      MEDIASTINUM  CT Lymph Nodes         524       CT
# 3          ABDOMEN  CT Lymph Nodes         661       CT
# 4          ABDOMEN  CT Lymph Nodes         735       CT
#
#          SeriesDescription                             SeriesInstanceUID  \
# 0    abdominal_lymph_nodes   61.7.68766114340462632891436074274610210906
# 1    abdominal_lymph_nodes  61.7.189884624733247751868911654633570519535
# 2  mediastinal_lymph_nodes   61.7.74372680982822357363687725488894558476
# 3    abdominal_lymph_nodes  61.7.111503609011979038458820141633166596150
# 4    abdominal_lymph_nodes  61.7.136109627500567814530333386506613155124
#
#                                StudyInstanceUID  Visibility
# 0    61.7.4614721973933394487739198448489366125           1
# 1  61.7.128876040172251404065414822554792863476           1
# 2  61.7.106011913688873777967000368671613390694           1
# 3  61.7.132633651985091577773125743369316426514           1
# 4  61.7.280655946894172429784728226992976023531           1

# %%
#Filter so each Series in the collection has >300 images.
#We can filter other things too later if we want.
res = pdfSeries[pdfSeries['ImageCount']>300]

# %%
#Randomly sample a series UID:
strSeriesUID = pdfSeries.sample(1).SeriesInstanceUID.values[0]
strSeriesUID
# Out:
# '61.7.290841801260861167894792203663273391457'

# %%
#How big is this series? BIG.
response = client.get_series_size(SeriesInstanceUID=strSeriesUID)
pandas.io.json.read_json(getResponseString(response))
# Out:
# https://services.cancerimagingarchive.net/services/v3/TCIA/query/getSeriesSize?SeriesInstanceUID=61.7.290841801260861167894792203663273391457&format=json
#    ObjectCount  TotalSizeInBytes
# 0          677         355703946

# %%
def download_series(uid, download_dir, zip_name):
    response = client.get_image(strSeriesUID, download_dir, zip_name)
    strResponseImage = getResponseString(response)

# %%
import os
if not os.path.isdir(f'./{lymph_series_name}'):
    os.mkdir(f'./{lymph_series_name}')

# %%
uids = res.SeriesInstanceUID
download_dir = f'./{lymph_series_name}'
for uid in uids:
    print(f'Downloading {uid}...')
    zip_name = uid
    download_series(uid, download_dir, zip_name)
# Out:
# Downloading 61.7.68766114340462632891436074274610210906...
# https://services.cancerimagingarchive.net/services/v3/TCIA/query/getImage?SeriesInstanceUID=61.7.290841801260861167894792203663273391457
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-76-23845f0a3777> in <module>
#       4     print(f'Downloading {uid}...')
#       5     zip_name = uid
# ----> 6     download_series(uid, download_dir, zip_name)
#
# <ipython-input-75-65de09c3abca> in download_series(uid, download_dir, zip_name)
#       1 def download_series(uid, download_dir, zip_name):
# ----> 2     response = client.get_image(strSeriesUID, download_dir, zip_name)
#       3     strResponseImage = getResponseString(response)
#
# ~/Desktop/Work/Tutoring/Wyzant/sarah_m/tciaclient.py in get_image(self, seriesInstanceUid, downloadPath, zipFileName)
#     155         try:
#     156             file = os.path.join(downloadPath, zipFileName)
# --> 157             resp = self.execute( serviceUrl , queryParameters)
#     158             downloaded = 0
#     159             CHUNK = 256 * 10240
#
# ~/Desktop/Work/Tutoring/Wyzant/sarah_m/tciaclient.py in execute(self, url, queryParameters)
#      43         print(requestUrl)
#      44         request = urllib.request.Request(url=requestUrl , headers=headers)
# ---> 45         resp = urllib.request.urlopen(request)
#      46         return resp
#      47
#
# ~/anaconda3/envs/data_science/lib/python3.6/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# ~/anaconda3/envs/data_science/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     524             req = meth(req)
#     525
# --> 526         response = self._open(req, data)
#     527
#     528         # post-process response
#
# ~/anaconda3/envs/data_science/lib/python3.6/urllib/request.py in _open(self, req, data)
#     542         protocol = req.type
#     543         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 544                                   '_open', req)
#     545         if result:
#     546             return result
#
# ~/anaconda3/envs/data_science/lib/python3.6/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# ~/anaconda3/envs/data_science/lib/python3.6/urllib/request.py in https_open(self, req)
#    1359         def https_open(self, req):
#    1360             return self.do_open(http.client.HTTPSConnection, req,
# -> 1361                 context=self._context, check_hostname=self._check_hostname)
#    1362
#    1363         https_request = AbstractHTTPHandler.do_request_
#
# ~/anaconda3/envs/data_science/lib/python3.6/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1319             except OSError as err: # timeout error
#    1320                 raise URLError(err)
# -> 1321             r = h.getresponse()
#    1322         except:
#    1323             h.close()
#
# ~/anaconda3/envs/data_science/lib/python3.6/http/client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# ~/anaconda3/envs/data_science/lib/python3.6/http/client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# ~/anaconda3/envs/data_science/lib/python3.6/http/client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# ~/anaconda3/envs/data_science/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# ~/anaconda3/envs/data_science/lib/python3.6/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1010                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1011                   self.__class__)
# -> 1012             return self.read(nbytes, buffer)
#    1013         else:
#    1014             return socket.recv_into(self, buffer, nbytes, flags)
#
# ~/anaconda3/envs/data_science/lib/python3.6/ssl.py in read(self, len, buffer)
#     872             raise ValueError("Read on closed or unwrapped SSL socket.")
#     873         try:
# --> 874             return self._sslobj.read(len, buffer)
#     875         except SSLError as x:
#     876             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# ~/anaconda3/envs/data_science/lib/python3.6/ssl.py in read(self, len, buffer)
#     629         """
#     630         if buffer is not None:
# --> 631             v = self._sslobj.read(len, buffer)
#     632         else:
#     633             v = self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
import zipfile

# %%
zipfilePath = ("./CT Lymph Node/61.7.189884624733247751868911654633570519535")
z = zipfile.ZipFile(zipfilePath)
z.extractall("./CT Lymph Node/")
z.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-15-17058734b5a4> in <module>
#       1 zipfilePath = ("./CT Lymph Node/61.7.189884624733247751868911654633570519535")
# ----> 2 z = zipfile.ZipFile(zipfilePath)
#       3 z.extractall("./CT Lymph Node/")
#       4 z.close()
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/zipfile.py in __init__(self, file, mode, compression, allowZip64)
#    1088             while True:
#    1089                 try:
# -> 1090                     self.fp = io.open(file, filemode)
#    1091                 except OSError:
#    1092                     if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: './CT Lymph Node/61.7.189884624733247751868911654633570519535'

# %%
# Out:
# aws_from_scratch.ipynb	download_ct.py	tcia_api_testing.ipynb
# aws_quickinit.txt	kaggle_data	tciaclient.py
# cancer_ic.ipynb		__pycache__	TCIA-Python3-Downloader
# cancer_ic.py		README.md	using_cli.ipynb
# CT Lymph Nodes		ssh_keys

# %%
import pandas as pd
import pandas
from tciaclient import TCIAClient
import zipfile

KEY = '65547902-6d69-4f5b-9857-fb1e724d3b90' 
client = TCIAClient(apiKey = KEY, baseUrl="https://services.cancerimagingarchive.net/services/v3",resource = "TCIA")

# %%
def getResponseString(response):
    try:
        return response.read()
    except:
        pass
    
def download_series(uid, download_dir, zip_name):
    response = client.get_image(uid, download_dir, zip_name)
    strResponseImage = getResponseString(response)
    
    
    
response = client.get_collection_values()
strRespCollections = getResponseString(response)
collections = pandas.io.json.read_json(strRespCollections)

lymph_series_name = collections['Collection'].loc[50]


#Grab the series for CT Lymph Nodes
response = client.get_series(modality="CT", collection=lymph_series_name)
strRespSeries = getResponseString(response)
pdfSeries = pandas.io.json.read_json(strRespSeries)

#Filter so each Series in the collection has >300 images.
#We can filter other things too later if we want.
res = pdfSeries[pdfSeries['ImageCount']>300]
# Out:
# https://services.cancerimagingarchive.net/services/v3/TCIA/query/getCollectionValues?format=json
# https://services.cancerimagingarchive.net/services/v3/TCIA/query/getSeries?Collection=CT+Lymph+Nodes&Modality=CT&format=json

# %%
res
# Out:
#                                 SeriesInstanceUID  \
# 0     61.7.68766114340462632891436074274610210906
# 1    61.7.189884624733247751868911654633570519535
# 2     61.7.74372680982822357363687725488894558476
# 3    61.7.111503609011979038458820141633166596150
# 4    61.7.136109627500567814530333386506613155124
# ..                                            ...
# 171  61.7.177743692879163737005564464483057532867
# 172   61.7.50609751867865247998649433908524202040
# 173   61.7.79564164942948321555380084959260719471
# 174  61.7.208187498033323636110451697839169152701
# 175  61.7.137032640290615606726307597263209689724
#
#                                  StudyInstanceUID Modality  \
# 0      61.7.4614721973933394487739198448489366125       CT
# 1    61.7.128876040172251404065414822554792863476       CT
# 2    61.7.106011913688873777967000368671613390694       CT
# 3    61.7.132633651985091577773125743369316426514       CT
# 4    61.7.280655946894172429784728226992976023531       CT
# ..                                            ...      ...
# 171  61.7.224551580232968831981674745224993612991       CT
# 172   61.7.75804546709586489027230621324719729481       CT
# 173  61.7.153281069320653076291058756736675514114       CT
# 174  61.7.267873646328970374394006298319963987879       CT
# 175   61.7.21951753007956806951356044993463016801       CT
#
#            SeriesDescription BodyPartExamined      Collection  Visibility  \
# 0      abdominal_lymph_nodes          ABDOMEN  CT Lymph Nodes           1
# 1      abdominal_lymph_nodes          ABDOMEN  CT Lymph Nodes           1
# 2    mediastinal_lymph_nodes      MEDIASTINUM  CT Lymph Nodes           1
# 3      abdominal_lymph_nodes          ABDOMEN  CT Lymph Nodes           1
# 4      abdominal_lymph_nodes          ABDOMEN  CT Lymph Nodes           1
# ..                       ...              ...             ...         ...
# 171    abdominal_lymph_nodes          ABDOMEN  CT Lymph Nodes           1
# 172  mediastinal_lymph_nodes      MEDIASTINUM  CT Lymph Nodes           1
# 173  mediastinal_lymph_nodes      MEDIASTINUM  CT Lymph Nodes           1
# 174    abdominal_lymph_nodes          ABDOMEN  CT Lymph Nodes           1
# 175  mediastinal_lymph_nodes      MEDIASTINUM  CT Lymph Nodes           1
#
#      ImageCount
# 0           717
# 1           517
# 2           524
# 3           661
# 4           735
# ..          ...
# 171         631
# 172         549
# 173         646
# 174         704
# 175         721
#
# [174 rows x 8 columns]

# %%
res.to_csv('./data/ct_lymph_nodes_series_data.csv')

# %%
import os

root = 'data/CT Lymph Nodes/'
for path in os.listdir(root):
    if '.zip' not in path:
        new_path = os.path.join(root,path)
        f = os.listdir(path)[0]
        annot_name = dicom.dcmread(os.path.join(new_path,f)).PatientName
        print(annot_name)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-42-66a130f06427> in <module>
#       5     if '.zip' not in path:
#       6         new_path = os.path.join(root,path)
# ----> 7         f = os.listdir(path)[0]
#       8         annot_name = dicom.dcmread(os.path.join(new_path,f)).PatientName
#       9         print(annot_name)
#
# FileNotFoundError: [Errno 2] No such file or directory: '61.7.91905844422421701161237158452768346088'

# %%
import os

paths = [os.path.join('data/CT Lymph Nodes/',d) for d in os.listdir('data/CT Lymph Nodes/') if '.zip' not in d]

annot_names = [dicom.dcmread(os.path.join(p,os.listdir(p)[0])).PatientName for p in old_paths]

name_map = dict(zip(annot_names, paths))

# %%
import pydicom as dicom

# %%
for f in os.listdir(path):
dicom.dcmread(os.path.join(path,os.listdir(path)[0])).PatientName
# Out:
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
# ABD_LYMPH_003
